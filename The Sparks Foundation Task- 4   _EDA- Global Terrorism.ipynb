# %% [markdown]
# # The Sparks Foundation: Task 4 - Exploratory Data Analysis - Global Terrorism (Level - Intermediate)

# %% [markdown]
# ## DATA SCIECNE AND BUSINESS ANALYTICS  INTERN: RASHMI KUMARI

# %% [markdown]
# ### Aim: As the Security/Defense Analyst , we have to find out the hot zone of Terrorism and insights out of it.
#
# Dataset link:https://bit.ly/2TK5Xn5

# %% [markdown]
# ![TERRORISM%20IMG.jpg](attachment:TERRORISM%20IMG.jpg)

# %% [raw]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline     

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
data=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1')
print("Data have been loaded successfully!!!")
# Out:
# Data have been loaded successfully!!!

# %% [markdown]
# ### observing the data and extracting bit information.

# %% [raw]
# The data string is of latin1 encoding instead of UTF-8 encoding.

# %% [raw]
# What is encoding ='latin1?
# Latin-1, also called ISO-8859-1, is an 8-bit character set endorsed by the International Organization for Standardization
# (ISO) and represents the alphabets of Western European languages.
#
# This is a type of encoding and is used to solve the UnicodeDecodeError, while attempting to read a file in Python or Pandas. latin-1 is a single-byte encoding which uses the characters 0 through 127.

# %%
# Knowledge about the dataset.

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
print("The Number of rows in the dataset is:",data.shape[0])
print("The Number of columns in the dataset is:",data.shape[1])
# Out:
# The Number of rows in the dataset is: 181691
# The Number of columns in the dataset is: 135

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.duplicated().sum()   #This shows no duplicated value is there in the given dataset.
# Out:
# 0

# %%
data.isnull().sum()   #Checking for the columns having null values.
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#As we are not able to view all the column name using the columns function.Thats why we need to do the following.

# %%
for i in data.columns:
    print(i,end='\n')
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %% [markdown]
# # Cleaning the data

# %%
#NOTE: We want some of the columns out of these much columns to work with, so we are not listing them as below.

# %%
data=data[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
data.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
#We can Rename the columns also , so that it will be easy to access any of the desired column using name defined by us.

# %%
data.rename(columns={"iyear":"Year",
                     "imonth":"Month",
                     "iday":"Day",
                     "country_txt":"Country",
                     "region_txt":"Region",
                     "provstate":"Province/State",
                     "city":"City",
                     "latitude":"Latitude",
                     "longitude":"Longitude",
                     "location":"Location",
                     "summary":"Summary",
                     "attacktype1_txt":"Attack Type",
                     "targtype1_txt":"Target Type",
                     "gname":"Group Name",
                     "motive":"Motive",
                     "weaptype1_txt":"Weapon Type",
                     "nkill":"Killed",
                     "nwound":"Wounded",
                     "addnotes":"Add Notes"},inplace=True)

# %%
data.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
#Again...

data.shape    # 19 columns we have choosen.
# Out:
# (181691, 19)

# %% [raw]
# # inplace=True ----> this modified the no. of rows and columns , entries and titles....stored in the variable data.

# %%
print("The Number of rows in the dataset is:",data.shape[0])
print("The Number of columns in the dataset is:",data.shape[1])
# Out:
# The Number of rows in the dataset is: 181691
# The Number of columns in the dataset is: 19

# %%
data.columns   #Gives all the column names present in the modified variable data.
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes'],
#       dtype='object')

# %%
data.info()    #Gives small description about the variable data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
#Count of values in each column of the dataset.
data.nunique()
# Out:
# Year                  47
# Month                 13
# Day                   32
# Country              205
# Region                12
# Province/State      2855
# City               36674
# Latitude           48322
# Longitude          48039
# Location           44109
# Summary           112492
# Attack Type            9
# Target Type           22
# Group Name          3537
# Motive             14490
# Weapon Type           12
# Killed               205
# Wounded              238
# Add Notes          15429
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# Add Notes         153402
# dtype: int64

# %%
data["Killed"]=data["Killed"].fillna(0)
data["Wounded"]=data["Wounded"].fillna(0)     #No more null values present in these two columns Killed and Wounded.

# %%
data.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed                 0
# Wounded                0
# Add Notes         153402
# dtype: int64

# %%
#Introducing a new column name Casualty happen as the sum of both Killed and Wounded.
data["Casualty happen"]=data["Killed"]+data["Wounded"]    # Killed , Wounded ,Casualty happen ---> all their values are 
                                                          #                                        in booelaen either 0 or 1.

data.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %% [markdown]
# ### Lets look at some numbers..

# %% [raw]
# #Now we Lets look into the following points ,so we have the columns as....
# columns :
#         'Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen']
#
#
# Lets Explore about..
#        1.Years in the Dataset.
#        2.Countries in the Dataset.
#        3.Check is India there in those above countries...extract its data.
#        4.Total count of ATTACK TYPE in the Dataset.
#        5.Total count of REGION in the Dataset.
#        6.Total count of CITIES in the Dataset.
#        7.Total count of TARGET TYPE in the Dataset.
#        8.Total count of GROUP NAME of terrorists in the Dataset.
#        9.Total count of Weapon Type they have used according to the dataset.
#        10.list of some motives behind the attacks.

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %%
#Years in the Dataset.
data['Year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
#Countries in the Dataset.
data['Country'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
#Check is India there in those above countries...extract its data.
data[data['Country']=='India']
# Out:
#         Year  Month  Day Country      Region     Province/State  \
# 1186    1972      2   22   India  South Asia              Delhi
# 2764    1975      1    2   India  South Asia              Bihar
# 3857    1976      5   26   India  South Asia              Delhi
# 5327    1977      9   28   India  South Asia        Maharashtra
# 7337    1979      1   13   India  South Asia              Assam
# ...      ...    ...  ...     ...         ...                ...
# 181663  2017     12   30   India  South Asia             Kerala
# 181665  2017     12   30   India  South Asia       Chhattisgarh
# 181672  2017     12   31   India  South Asia  Jammu and Kashmir
# 181684  2017     12   31   India  South Asia              Assam
# 181689  2017     12   31   India  South Asia            Manipur
#
#                  City   Latitude  Longitude  \
# 1186        New Delhi  28.585836  77.153336
# 2764       Samastipur  25.863042  85.781004
# 3857        New Delhi  28.585836  77.153336
# ...

# %%
#Total count of ATTACK TYPE in the Dataset.
data['Attack Type'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack Type, dtype: int64

# %%
#Total count of REGION in the Dataset.
data['Region'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
#Total count of CITIES in the Dataset.
data['City'].value_counts()
# Out:
# Unknown      9775
# Baghdad      7589
# Karachi      2652
# Lima         2359
# Mosul        2265
#              ...
# Hotwag          1
# Ostend          1
# Balughata       1
# Jikoyi          1
# Kubentog        1
# Name: City, Length: 36674, dtype: int64

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %%
#Total count of TARGET TYPE in the Dataset.
data['Target Type'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target Type, dtype: int64

# %%
#Total count of GROUP NAME of terrorists in the Dataset.
data['Group Name'].value_counts()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Ansar Sarallah                                          1
# Sword of Islam                                          1
# Support of Ocalan-The Hawks of Thrace                   1
# Arab Revolutionary Front                                1
# MANO-D                                                  1
# Name: Group Name, Length: 3537, dtype: int64

# %%
#Total count of Weapon Type they have used according to the dataset.
data['Weapon Type'].value_counts()
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
#list of some motives behind the attacks.
pd.DataFrame(data['Motive'].value_counts())
# Out:
#                                                     Motive
# Unknown                                              14889
# The specific motive for the attack is unknown.       14430
# The specific motive is unknown; however, source...     297
# The specific motive for the attack is unknown..        148
# The specific motive for the attack is unknown o...     144
# ...                                                    ...
# Doka Umarov and the Riyadus-Salikhin Battalion ...       1
# The attack was carried out  to protest the visi...       1
# Authorities suspect the motive of the attack wa...       1
# The specific motive for the attack is unknown; ...       1
# The specific motive is unknown; however, source...       1
#
# [14490 rows x 1 columns]

# %%
#Statistical Summary of Data.
data.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded  Casualty happen
# count  1.771340e+05  181691.000000  181691.000000    181691.000000
# mean  -4.586957e+02       2.266860       2.883296         5.150156
# std    2.047790e+05      11.227057      34.309747        40.555416
# min   -8.618590e+07       0.000000       0.000000         0.000000
# ...

# %% [raw]
# Information we extract from the above statistical data.
#
# The data consists of:
#
# * Terrorist activities in years from : 1970 to 2017
#
# * Maximum number of people killed in an event were: 1570
#
# * Maximum number of people wounded in an event were: 8191
#
# * Maximum number of total casualties happen in an event were: 9574

# %%
#Correlation among the columns.
data.corr()
# Out:
#                      Year     Month       Day  Latitude  Longitude    Killed  \
# Year             1.000000  0.000139  0.018254  0.166933   0.003917  0.021252
# Month            0.000139  1.000000  0.005497 -0.015978  -0.003880  0.004031
# Day              0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003225
# Latitude         0.166933 -0.015978  0.003423  1.000000   0.001463 -0.013170
# Longitude        0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000587
# Killed           0.021252  0.004031 -0.003225 -0.013170  -0.000587  1.000000
# Wounded          0.017484  0.003178 -0.001082  0.015920   0.000205  0.443326
# Casualty happen  0.020675  0.003805 -0.001808  0.009899   0.000013  0.651885
#
#                   Wounded  Casualty happen
# Year             0.017484         0.020675
# Month            0.003178         0.003805
# Day             -0.001082        -0.001808
# Latitude         0.015920         0.009899
# Longitude        0.000205         0.000013
# ...

# %% [raw]
# Note:'Casualty happen' shows high correlation with 'Killed'and 'Wounded' because , this column 'Casualty happen' is
# made up with the combination of 'Killed' and 'Wounded' columns.

# %% [markdown]
# # Visualization of Data

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %%
#Pie Plot of REGION.

plt.figure(figsize=(10,10))
data['Region'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()
plt.show()

# %%
#Pie Plot of ATTACK TYPE.

plt.figure(figsize=(10,10))
data['Attack Type'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()

# %%
#Pie Plot of WEAPON TYPE.

plt.figure(figsize=(10,10))
data['Weapon Type'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()

# %%
#Pie Plot of TARGET TYPE.

plt.figure(figsize=(10,10))
data['Target Type'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()

# %% [raw]
# Summary Area occupied by Pie Plots:
#     1.Maximum REGION is Middle East & North Africa , about 27.8 %
#     2.Maximum ATTACK TYPE is Bombing/Explosion , about 48.6%
#     3.Most used WEAPON TYPE is Explosives , about 50.9%
#     4.Maximum TARGET TYPE is Private Citizens & Property

# %% [markdown]
# ### (A).  Counting of Terrorist Attacks w.r.t Year,Region,wepon type,attack type.

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %%
#Years with Most Terrorist Attacks


plt.figure(figsize=(20,10))
sns.countplot(data['Year'])

plt.title("Number of Attacks in Years",fontsize='18')
plt.xlabel("Year",fontsize='18')
plt.ylabel("Count of Attacks",fontsize='18')
plt.xticks(rotation='45')
plt.show()

# %%
#Region wise with Most Terrorist Attacks


plt.figure(figsize=(20,10))
sns.countplot(data['Region'])

plt.title("Number of Attacks RegionWise",fontsize='18')
plt.xlabel("Region",fontsize='18')
plt.ylabel("Count of Attacks",fontsize='18')
plt.xticks(rotation='45')
plt.show()

# %%
#Weapon Used in Most of the Terrorist Attacks


plt.figure(figsize=(20,10))
sns.countplot(data['Weapon Type'])

plt.title("Weapon Used in Most of the Terrorist Attacks",fontsize='18')
plt.xlabel("Weapon Type",fontsize='18')
plt.ylabel("Count of Attacks",fontsize='18')
plt.xticks(rotation='45')
plt.show()

# %%
#Targeted Group  Mostly for Terrorist Attacks.


plt.figure(figsize=(20,10))
sns.countplot(data['Target Type'])

plt.title("Targeted Group  Mostly for Terrorist Attacks.",fontsize='18')
plt.xlabel("Target Type",fontsize='18')
plt.ylabel("Count of Attacks",fontsize='18')
plt.xticks(rotation='45')
plt.show()

# %% [raw]
# Summary out of these bar charts:
#
#     1.Years with Most Terrorist Attacks  : 2014
#     2.Region wise with Most Terrorist Attacks  : Middle East & North Africa
#     3.Weapon Used in Most of the Terrorist Attacks : Explosives
#     4.Targeted Group  Mostly for Terrorist Attacks : Private Citizens & Property

# %% [markdown]
# ### (B). Affected TOP 10 ----> Countries,Region,City,Province/State.

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %%
#Affected Top 10 Countries:

plt.figure(figsize=(20,10))
sns.barplot(data['Country'].value_counts()[:10].index,
            data['Country'].value_counts()[:10].values)
plt.title("Top 10 Affected Countries",fontsize=15)
plt.xlabel('Countries Affected ',fontsize=15)
plt.ylabel("Count of Attacks",fontsize=15)
plt.show()

# %%
#Note: Iraq,Pakistan,Afghanistan and India comes in top 4....India comes at 4th.

# %%
#Affected Top 10 Region:

plt.figure(figsize=(20,10))
sns.barplot(data['Region'].value_counts()[:10].index,
            data['Region'].value_counts()[:10].values)
plt.title("Top 10 Affected Regions",fontsize=15)
plt.xlabel('Regions Affected ',fontsize=15)
plt.ylabel("Count of Attacks",fontsize=15)
plt.xticks(rotation=30)
plt.show()

# %%
#Affected Top 10 Province/State:

plt.figure(figsize=(20,10))
sns.barplot(data['Province/State'].value_counts()[:10].index,
            data['Province/State'].value_counts()[:10].values)
plt.title("Top 10 Affected Province/State",fontsize=15)
plt.xlabel('Province/State Affected ',fontsize=15)
plt.ylabel("Count of Attacks",fontsize=15)
plt.xticks(rotation=30)
plt.show()

# %%
#Most Involved Terrorist Group.

data['Group Name'].value_counts().head(10)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Group Name, dtype: int64

# %%
# TOP 10 Terrorist group name.
plt.figure(figsize=(10,5))
sns.barplot(data['Group Name'].value_counts()[:10].index,
            data['Group Name'].value_counts()[:10].values)

plt.title("Most Involved Terrorist Groups",fontsize=15)
plt.xlabel("Terrorist Group",fontsize=15)
plt.ylabel("Count of Attacks",fontsize=15)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %% [raw]
# Summary out of top 10 affected data with Attacks:
#     1.Country with the highest number of Terrorist attacks: IRAQ
#     2.Region with the highest number of Terrorist attacks : MIDDLE EAST & NORTH AFRIA.
#     3.State with the highest number of Terrorist attacks  : BAGHDAD
#     4.Most Involved Terrorist Group with the highest number of attacks : Unknown

# %% [raw]
# Lets Look into INDIA:

# %%
india=data[data['Country']=='India']['Province/State']
india.value_counts()
# Out:
# Jammu and Kashmir    2454
# Assam                1151
# Manipur              1100
# Chhattisgarh          979
# Punjab                949
# Jharkhand             887
# Bihar                 688
# West Bengal           650
# Odisha                428
# Maharashtra           302
# Meghalaya             294
# Andhra Pradesh        251
# Orissa                221
# Delhi                 208
# Uttar Pradesh         201
# Tamil Nadu            164
# Unknown               157
# Tripura               117
# Nagaland              115
# Kerala                 98
# Gujarat                85
# Madhya Pradesh         75
# Karnataka              71
# Haryana                50
# Chandigarh             47
# Rajasthan              43
# Andhra pradesh         41
# Mizoram                27
# Uttaranchal            24
# Himachal Pradesh       24
# Arunachal Pradesh      24
# Telangana              24
# Goa                     5
# Sikkim                  4
# Puducherry              2
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(india.value_counts()[:10].index,
            india.value_counts()[:10].values)

plt.title("Top 10 Affected States of India by terrorist attacks",fontsize=15)
plt.xlabel("Province/State",fontsize=15)
plt.ylabel("Count of Attacks",fontsize=15)
plt.xticks(rotation=45,fontsize=12)

plt.show()

# %% [markdown]
# ### Analyze the Number of PEOPLE GOT KILLED,GOT WOUNDED AND CASUALTIES HAPPENED.

# %% [markdown]
# ## PEOPLE GOT KILLED

# %% [raw]
# (A).1.PEOPLE GOT KILLED Yearwise.

# %%
year_killed=data[["Year","Killed"]].groupby("Year").sum()   #We grouped the dataset on 2 factors killed and year.
year_killed.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
year_killed.plot(kind="bar",color="red",figsize=(10,5))
plt.title("People Killed in each Year")
plt.xlabel("Years",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).2.PEOPLE GOT KILLED Regionwise.

# %%
region_killed=data[["Region","Killed"]].groupby("Region").sum().sort_values(by="Killed",ascending=False)
region_killed
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
region_killed.plot(kind="bar",color="orange",figsize=(10,5))
plt.title("People Killed in each Region")
plt.xlabel("Regions",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).3.PEOPLE GOT KILLED countrywise attacks (Top 10).

# %%
country_killed=data[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
country_killed.head(10)
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0

# %%
country_killed[:10].plot(kind="bar",color="green",figsize=(10,5))
plt.title("Top 10 Countries were People got Killed maximum.")
plt.xlabel("Countires",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).4.PEOPLE GOT KILLED citywise attacks (Top 10).

# %%
city_killed=data[["City","Killed"]].groupby("City").sum().sort_values(by="Killed",ascending=False)
city_killed.head(10)
# Out:
#                 Killed
# City
# Unknown        22647.0
# Baghdad        21151.0
# Mosul           7140.0
# Mogadishu       3913.0
# Karachi         3688.0
# New York City   2838.0
# Tikrit          2679.0
# Kabul           2493.0
# Ramadi          2313.0
# Maiduguri       2235.0

# %%
city_killed[:10].plot(kind="bar",color="navy",figsize=(10,5))
plt.title("Top 10 Cities were People got Killed maximum.")
plt.xlabel("Cities",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).5.PEOPLE GOT KILLED by which  (Top 10) Terrorist group attacks more.

# %%
group_killed=data[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
group_killed.head(10)
# Out:
#                                                    Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)       38923.0
# Taliban                                           29410.0
# Boko Haram                                        20328.0
# Shining Path (SL)                                 11601.0
# Liberation Tigers of Tamil Eelam (LTTE)           10989.0
# Al-Shabaab                                         9330.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6042.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %%
group_killed[:10].plot(kind="bar",color="red",figsize=(10,5))    #Other than Unknown Groups.
plt.title("Top 10 Terrorist Group , People got Killed by.")
plt.xlabel("Terrorist Group Name",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).6.PEOPLE GOT KILLED by Attack Types.

# %%
attack_killed=data[["Attack Type","Killed"]].groupby("Attack Type").sum().sort_values(by="Killed",ascending=False)
attack_killed
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Unknown                               32381.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %%
attack_killed[:10].plot(kind="bar",color="lightgreen",figsize=(10,5))    
plt.title("Top 10 Attack type in which, People got Killed by.")
plt.xlabel("Attack Type",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).7.PEOPLE GOT KILLED , Target Typewise Attacks.

# %%
target_killed=data[["Target Type","Killed"]].groupby("Target Type").sum().sort_values(by="Killed",ascending=False)
target_killed
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     140504.0
# Military                        106047.0
# Police                           53704.0
# Government (General)             26071.0
# Business                         23487.0
# Transportation                   13916.0
# Religious Figures/Institutions   13413.0
# Terrorists/Non-State Militia      9088.0
# Unknown                           4329.0
# Airports & Aircraft               3767.0
# Educational Institution           3745.0
# Violent Political Party           3617.0
# Government (Diplomatic)           3039.0
# Utilities                         1874.0
# Journalists & Media               1501.0
# Maritime                          1191.0
# NGO                               1057.0
# Tourists                           758.0
# Food or Water Supply               313.0
# Other                              255.0
# Telecommunication                  182.0
# ...

# %%
target_killed.plot(kind="bar",color="green",figsize=(10,5))    
plt.title("Target typewise attacks  , People got Killed in.")
plt.xlabel("Target Type",fontsize=12)
plt.ylabel("Number of People Killed",fontsize=12) 
plt.show()

# %% [raw]
# (A).8.PEOPLE GOT KILLED , Groupwise and Countrywise  Attacks.   (GroupBy on 3 factors :"Group Name","Country","Killed")

# %%
gc_killed=data[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
gc_killed
# Out:
#                                                                Killed
# Group Name                                       Country
# Islamic State of Iraq and the Levant (ISIL)      Iraq         31058.0
# Taliban                                          Afghanistan  29269.0
# Boko Haram                                       Nigeria      16917.0
# Shining Path (SL)                                Peru         11595.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka    10928.0
# Al-Shabaab                                       Somalia       8176.0
# Farabundo Marti National Liberation Front (FMLN) El Salvador   8019.0
# Islamic State of Iraq and the Levant (ISIL)      Syria         6883.0
# Nicaraguan Democratic Force (FDN)                Nicaragua     6630.0
# Tehrik-i-Taliban Pakistan (TTP)                  Pakistan      6014.0

# %%
gc_killed.plot(kind="bar",color="navy",figsize=(10,5))                         
plt.title("Countries with most people killed by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group , Country)",fontsize=13)
plt.xticks(fontsize=10)
plt.ylabel("Number of people Killed",fontsize=13)     #Comes in a kind of pair.Terrorist Group ,Country
plt.show()

# %% [raw]
# (A).9.Humanity Affected( WORLD-WIDE) by Terrorist Attacks from 1970 to 2017.

# %%
kill=data.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  411868.0

# %% [raw]
# -----------------------------------SUMMARY OF 'KILLED' COLUMNS---------------------------------------

# %% [raw]
# Summary :PEOPLE KILLED
# 1.Year wise Attacks:
#     (a) Most number of people killed: 44490 in 2014
#     (b) Least number of people killed: 173 in 1971
#
# 2.Region wise Attacks:
#     (a) Most number of people killed: 137642 in "Middle East & North Africa"
#     (b) Least number of people killed: 150 in "Australasia & Oceania"
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of people killed: 78589 in "Iraq"
#     (b) Least number of people killed: 12053 in "El Salvador"
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of people killed: 21151 in "Baghdad"
#     (b) Least number of people killed: 2125 in "Aleppo"
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of people killed : 38923 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of people killed : 5661 by "Revolutionary Armed Forces of Colombia (FARC)"
#
# 6.Attack Type wise Attacks:
#     (a) Most number of people killed : 160297 by "Armed Assault"
#     (b) Least number of people killed : 880 by "Unarmed Assault"
#
# 7.Target Type wise Attacks:
#     (a) Most number of people killed : 140504 over "Private Citizens & Property"
#     (b) Least number of people killed : 10 over "Abortion Related"
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of people killed : 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
#     (b) Least number of people killed : 6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#      Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868

# %% [markdown]
# ## PEOPLE GOT WOUNDED

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %% [raw]
# (B).1.PEOPLE GOT WOUNDED Yearwise.

# %%
year_wounded=data[["Year","Wounded"]].groupby("Year").sum()   #We grouped the dataset on 2 factors Wounded and year.
year_wounded.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
year_wounded.plot(kind="bar",color="red",figsize=(10,5))
plt.title("People Wounded in each Year")
plt.xlabel("Year",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).2.PEOPLE GOT WOUNDED Regionwise.

# %%
region_wounded=data[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
region_wounded
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
region_wounded.plot(kind="bar",color="green",figsize=(10,5))
plt.title("People Wounded in each Region")
plt.xlabel("Region",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).3.PEOPLE GOT WOUNDED Countrywise attack (Top 10).

# %%
country_wounded=data[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
country_wounded.head(10)
# Out:
#                 Wounded
# Country
# Iraq           134690.0
# Afghanistan     44277.0
# Pakistan        42038.0
# India           28980.0
# United States   20702.0
# Sri Lanka       15561.0
# Syria           14109.0
# Philippines     13367.0
# Lebanon         10904.0
# Colombia        10328.0

# %%
country_wounded[:10].plot(kind="bar",color="orange",figsize=(10,5))
plt.title("Top 10 People got wounded Countrywise")
plt.xlabel("Countries",fontsize=12)
plt.ylabel("Number of People got wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).4.PEOPLE GOT WOUNDED citywise attacks (Top 10).

# %%
city_wounded=data[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded",ascending=False)
city_wounded.head(10)
# Out:
#                Wounded
# City
# Baghdad        56725.0
# New York City  16781.0
# Unknown        12803.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0

# %%
city_wounded[:10].plot(kind="bar",color="navy",figsize=(10,5))
plt.title("Top 10 Cities were People got Wounded maximum.")
plt.xlabel("Cities",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).5.PEOPLE GOT WOUNDED by which  (Top 10) Terrorist group attacks more.

# %%
group_wounded=data[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
group_wounded.head(10)
# Out:
#                                              Wounded
# Group Name
# Islamic State of Iraq and the Levant (ISIL)  30672.0
# Taliban                                      27932.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      11031.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9532.0
# Boko Haram                                    9473.0
# Al-Shabaab                                    7624.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4908.0

# %%
group_wounded[:10].plot(kind="bar",color="green",figsize=(10,5))
plt.title("Top 10 Countries with most people wounded by a particular Group")
plt.xlabel("Terrorist Group name ",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).6.PEOPLE GOT WOUNDED by Attack Types.

# %%
attack_wounded=data[["Attack Type","Wounded"]].groupby("Attack Type").sum().sort_values(by="Wounded",ascending=False)
attack_wounded
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    372686.0
# Armed Assault                         77366.0
# Hijacking                             17001.0
# Unknown                               14725.0
# Unarmed Assault                       14027.0
# Assassination                         13887.0
# Hostage Taking (Kidnapping)            6446.0
# Hostage Taking (Barricade Incident)    3966.0
# Facility/Infrastructure Attack         3765.0

# %%
attack_wounded[:10].plot(kind="bar",color="lightgreen",figsize=(10,5))    
plt.title("Top 10 Attack type in which, People got Wounded by.")
plt.xlabel("Attack Type",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).7.PEOPLE GOT WOUNDED , Target Typewise Attacks.

# %%
target_wounded=data[["Target Type","Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded",ascending=False)
target_wounded
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     178672.0
# Military                         71038.0
# Police                           64703.0
# Business                         54531.0
# Government (General)             41184.0
# Transportation                   40679.0
# Religious Figures/Institutions   24477.0
# Government (Diplomatic)          10359.0
# Educational Institution          10227.0
# Terrorists/Non-State Militia      8223.0
# Violent Political Party           5303.0
# Unknown                           3559.0
# Airports & Aircraft               3478.0
# Journalists & Media               1796.0
# Utilities                         1353.0
# Tourists                          1290.0
# Maritime                           908.0
# NGO                                893.0
# Telecommunication                  497.0
# Other                              419.0
# Food or Water Supply               234.0
# ...

# %%
target_wounded.plot(kind="bar",color="green",figsize=(10,5))    
plt.title("Target typewise attacks  , People got Wounded in.")
plt.xlabel("Target Type",fontsize=12)
plt.ylabel("Number of People Wounded",fontsize=12) 
plt.show()

# %% [raw]
# (B).8.PEOPLE GOT WOUNDED , Groupwise and Countrywise  Attacks.   (GroupBy on 3 factors :"Group Name","Country","Wounded")

# %%
gc_wounded=data[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
gc_wounded
# Out:
#                                                            Wounded
# Group Name                                  Country
# Taliban                                     Afghanistan    27871.0
# Islamic State of Iraq and the Levant (ISIL) Iraq           23697.0
# Al-Qaida                                    United States  16493.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka      10991.0
# Al-Qaida in Iraq                            Iraq           10075.0
# Tehrik-i-Taliban Pakistan (TTP)             Pakistan        9518.0
# Boko Haram                                  Nigeria         7671.0
# Al-Shabaab                                  Somalia         6025.0
# Aum Shinri Kyo                              Japan           6003.0
# Kurdistan Workers' Party (PKK)              Turkey          4795.0

# %%
gc_wounded.plot(kind="bar",color="navy",figsize=(10,5))                         
plt.title("Countries with most people wounded by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group , Country)",fontsize=13)
plt.xticks(fontsize=10)
plt.ylabel("Number of people Wounded",fontsize=13)     #Comes in a kind of pair.Terrorist Group ,Country
plt.show()

# %% [raw]
# (B).9.Humanity Affected( WORLD-WIDE) by Terrorist Attacks from 1970 to 2017.

# %%
wound=data.loc[:,"Wounded"].sum()
print("Total number of people Wounded due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people Wounded due to Terrorist Attacks from 1970 to 2017 across the world :
#  523869.0

# %% [raw]
# -----------------------------------------SUMMARY OF WOUNDED COLUMN------------------------------------------

# %% [raw]
# Summary :PEOPLE WOUNDED
#
# 1.Year wise Attacks :
#     (a) Most number of people wounded: 44043 in 2015
#     (b) Least number of people wounded: 82 in 1971
#
# 2.Region wise Attacks :
#     (a) Most number of people wounded: 214308 in "Middle East & North Africa"
#     (b) Least number of people wounded: 260 in "Australasia & Oceania"
#
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of people wounded: 134690 in "Iraq"
#     (b) Least number of people wounded: 10328 in "Colombia"
#
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of people wounded: 56725 in "Baghdad"
#     (b) Least number of people wounded: 4955 in "Mogadishu"
#
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of people wounded : 30672 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of people wounded : 4908 by "Kurdistan Workers' Party (PKK)"
#
# 6.Attack Type wise Attacks:
#     (a) Most number of people wounded : 372686 by "Bombing/Explosion"
#     (b) Least number of people wounded : 3765 by "Facility/Infrastructure Attack"
#
#
#
# 7.Target Type wise Attacks:
#     (a) Most number of people wounded : 178672 over "Private Citizens & Property"
#     (b) Least number of people wounded : 46 over "Abortion Related"
#
#
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of people wounded : 27871 by "Taliban" in "Afghanistan"
#     (b) Least number of people wounded : 4795 by "Kurdistan Workers' Party (PKK)" in "Turkey"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#     Total number of people wounded due to Terrorist Attacks from 1970 to 2017 across the world : 523869.0

# %% [markdown]
# ## CASUALITIES HAPPEN

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes', 'Casualty happen'],
#       dtype='object')

# %% [raw]
# (C).1.CASUALITIES HAPPEN Yearwise.

# %%
year_Casualities=data[["Year","Casualty happen"]].groupby("Year").sum()   #We grouped the dataset on 2 factors Casualty 
                                                                          #happen and year.
year_Casualities.head()
# Out:
#       Casualty happen
# Year
# 1970            386.0
# 1971            255.0
# 1972            975.0
# 1973            865.0
# 1974           1404.0

# %%
year_Casualities.plot(kind="bar",color="red",figsize=(10,5))
plt.title("Casualities happen Yearwise")
plt.xlabel("Year",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).2.CASUALITIES HAPPEN Regionwise.

# %%
region_Casualities=data[["Region","Casualty happen"]].groupby("Region").sum().sort_values(by="Casualty happen",ascending=False)

                                                #We grouped the dataset on 2 factors Casualty happen and year.
region_Casualities.head()
# Out:
#                             Casualty happen
# Region
# Middle East & North Africa         351950.0
# South Asia                         242679.0
# Sub-Saharan Africa                 131243.0
# South America                       45553.0
# Southeast Asia                      41896.0

# %%
region_Casualities.plot(kind="bar",color="green",figsize=(10,5))
plt.title("Casualities happen Regionwise")
plt.xlabel("Region",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).3.CASUALITIES HAPPEN Countrywise attack (Top 10).

# %%
country_Casualities=data[["Country","Casualty happen"]].groupby("Country").sum().sort_values(by="Casualty happen",ascending=False)
country_Casualities.head(10)
# Out:
#                Casualty happen
# Country
# Iraq                  213279.0
# Afghanistan            83661.0
# Pakistan               65860.0
# India                  48321.0
# Nigeria                32921.0
# Sri Lanka              31091.0
# Syria                  29338.0
# Colombia               25026.0
# United States          24473.0
# Philippines            22926.0

# %%
country_Casualities[:10].plot(kind="bar",color="orange",figsize=(10,5))
plt.title("Top 10 Casualities happen Countrywise")
plt.xlabel("Countries",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (B).4.CASUALITIES HAPPEN citywise attacks (Top 10).

# %%
city_Casualities=data[["City","Casualty happen"]].groupby("City").sum().sort_values(by="Casualty happen",ascending=False)
city_Casualities.head(10)
# Out:
#                Casualty happen
# City
# Baghdad                77876.0
# Unknown                35450.0
# New York City          19619.0
# Mosul                  12927.0
# Karachi                 9376.0
# Mogadishu               8868.0
# Kabul                   8466.0
# Beirut                  7257.0
# Kirkuk                  6636.0
# Colombo                 5906.0

# %%
city_Casualities[:10].plot(kind="bar",color="red",figsize=(10,5))
plt.title("Top 10 Casualities happen Citywise")
plt.xlabel("Cities",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).5.CASUALITIES HAPPEN by which  (Top 10) Terrorist group attacks more.

# %%
group_casualities=data[["Group Name","Casualty happen"]].groupby("Group Name").sum().sort_values(by="Casualty happen",ascending=False).drop("Unknown")
group_casualities.head(10)
# Out:
#                                                   Casualty happen
# Group Name
# Islamic State of Iraq and the Levant (ISIL)               69595.0
# Taliban                                                   57342.0
# Boko Haram                                                29801.0
# Al-Qaida                                                  28372.0
# Liberation Tigers of Tamil Eelam (LTTE)                   22020.0
# Al-Shabaab                                                16954.0
# Tehrik-i-Taliban Pakistan (TTP)                           15574.0
# Al-Qaida in Iraq                                          14724.0
# Shining Path (SL)                                         14632.0
# Farabundo Marti National Liberation Front (FMLN)          12130.0

# %%
group_casualities[:10].plot(kind="bar",color="green",figsize=(10,5))
plt.title("Casualities by Particular Group")
plt.xlabel("Terrorist Group name ",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).6.CASUALITIES by Attack Types.

# %%
attack_casualities=data[["Attack Type","Casualty happen"]].groupby("Attack Type").sum().sort_values(by="Casualty happen",ascending=False)
attack_casualities
# Out:
#                                      Casualty happen
# Attack Type
# Bombing/Explosion                           530007.0
# Armed Assault                               237663.0
# Unknown                                      47106.0
# Assassination                                38807.0
# Hostage Taking (Kidnapping)                  30677.0
# Hijacking                                    20719.0
# Unarmed Assault                              14907.0
# Hostage Taking (Barricade Incident)           8444.0
# Facility/Infrastructure Attack                7407.0

# %%
attack_casualities[:10].plot(kind="bar",color="lightgreen",figsize=(10,5))    
plt.title("Top 10 Attack type in which, Casualities happen.")
plt.xlabel("Attack Type",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).7.CASUALITIES HAPPEN , Target Typewise Attacks.

# %%
target_casualities=data[["Target Type","Casualty happen"]].groupby("Target Type").sum().sort_values(by="Casualty happen",ascending=False)
target_casualities
# Out:
#                                 Casualty happen
# Target Type
# Private Citizens & Property            319176.0
# Military                               177085.0
# Police                                 118407.0
# Business                                78018.0
# Government (General)                    67255.0
# Transportation                          54595.0
# Religious Figures/Institutions          37890.0
# Terrorists/Non-State Militia            17311.0
# Educational Institution                 13972.0
# Government (Diplomatic)                 13398.0
# Violent Political Party                  8920.0
# Unknown                                  7888.0
# Airports & Aircraft                      7245.0
# Journalists & Media                      3297.0
# Utilities                                3227.0
# Maritime                                 2099.0
# Tourists                                 2048.0
# NGO                                      1950.0
# ...

# %%
target_casualities.plot(kind="bar",color="green",figsize=(10,5))    
plt.title("Target typewise attacks  ,Casualities happen.")
plt.xlabel("Target Type",fontsize=12)
plt.ylabel("Number of Casualities occured",fontsize=12) 
plt.show()

# %% [raw]
# (C).8.CASUALITIES HAPPEN, Groupwise and Countrywise  Attacks. (GroupBy on 3 factors :"Group Name","Country","Casualty happen")

# %%
gc_casualities=data[["Group Name","Country","Casualty happen"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty happen",ascending=False).drop("Unknown").head(10)
gc_casualities
# Out:
#                                                                 Casualty happen
# Group Name                                       Country
# Taliban                                          Afghanistan            57140.0
# Islamic State of Iraq and the Levant (ISIL)      Iraq                   54755.0
# Boko Haram                                       Nigeria                24588.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka              21919.0
# Al-Qaida                                         United States          19494.0
# Tehrik-i-Taliban Pakistan (TTP)                  Pakistan               15532.0
# Shining Path (SL)                                Peru                   14625.0
# Al-Qaida in Iraq                                 Iraq                   14348.0
# Al-Shabaab                                       Somalia                14201.0
# Farabundo Marti National Liberation Front (FMLN) El Salvador            12068.0

# %%
gc_casualities.plot(kind="bar",color="navy",figsize=(10,5))                         
plt.title("Countries with most Casualty happen by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group , Country)",fontsize=13)
plt.xticks(fontsize=10)
plt.ylabel("Number of Casualities occured",fontsize=13)     #Comes in a kind of pair.Terrorist Group ,Country
plt.show()

# %% [raw]
# (B).9.Humanity Affected( WORLD-WIDE) by Terrorist Attacks from 1970 to 2017.

# %%
casualities=data.loc[:,"Casualty happen"].sum()
print("Total number of Casualty happen due to Terrorist Attacks from 1970 to 2017 across the world :\n",casualities)
# Out:
# Total number of Casualty happen due to Terrorist Attacks from 1970 to 2017 across the world :
#  935737.0

# %% [raw]
# ----------------------------------------SUMMARY OF CASUALTY HAPPEN COLUMN----------------------------------

# %% [raw]
# SUMMARY OF CASUALITIES HAPPEN :
# 1.Year wise Attacks :
#     (a) Most number of casualties: 85618 in 2014
#     (b) Least number of casualties: 255 in 1971
#
# 2.Region wise Attacks :
#     (a) Most number of casualties: 351950 in "Middle East & North Africa"
#     (b) Least number of casualties: 410 in Australasia & Oceania
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of casualties: 213279 in "Iraq"
#     (b) Least number of casualties: 22926 in "Philippines"
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of casualties: 77876 in "Baghdad"
#     (b) Least number of casualties: 5748 in "Aleppo"
#
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of casualties : 69595 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of casualties : 12130 by "Farabundo Marti National Liberation Front (FMLN)"
#
#
# 6.Attack Type wise Attacks:
#     (a) Most number of casualties : 530007 by "Bombing/Explosion"
#     (b) Least number of casualties : 7407 by "Facility/Infrastructure Attack"
#
# 7.Target Type wise Attacks:
#     (a) Most number of casualties : 319176 over "Private Citizens & Property"
#     (b) Least number of casualties : 56 over "Abortion Related"
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of casualties : 57140 by "Taliban" in "Afghanistan"
#     (b) Least number of casualties : 12068 by "Farabundo Marti National Liberation Front (FMLN)" in "El Salvador"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#     Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : 935737

# %% [markdown]
# # SUMMARY

# %% [raw]
# * Summary Area occupied by Pie Plots:
#     1.Maximum REGION is Middle East & North Africa , about 27.8 %
#     2.Maximum ATTACK TYPE is Bombing/Explosion , about 48.6%
#     3.Most used WEAPON TYPE is Explosives , about 50.9%
#     4.Maximum TARGET TYPE is Private Citizens & Property
#
#
# * Summary out of these bar charts:
#
#     1.Years with Most Terrorist Attacks  : 2014
#     2.Region wise with Most Terrorist Attacks  : Middle East & North Africa
#     3.Weapon Used in Most of the Terrorist Attacks : Explosives
#     4.Targeted Group  Mostly for Terrorist Attacks : Private Citizens & Property
#
# * Summary out of top 10 affected data with Attacks:
#     1.Country with the highest number of Terrorist attacks: IRAQ
#     2.Region with the highest number of Terrorist attacks : MIDDLE EAST & NORTH AFRIA.
#     3.State with the highest number of Terrorist attacks  : BAGHDAD
#     4.Most Involved Terrorist Group with the highest number of attacks : Unknown
#
# * Lets Look into INDIA:  Top 10 data of states attacked in INDIA.
#     Jammu and Kashmir    2454
#     Assam                1151
#     Manipur              1100
#     Chhattisgarh          979
#     Punjab                949
#     Jharkhand             887
#     Bihar                 688
#     West Bengal           650
#     Odisha                428
#     Maharashtra           302
# ------------------------------------------------------------------------------------
# * KILLED
#
# Summary :PEOPLE KILLED
# 1.Year wise Attacks:
#     (a) Most number of people killed: 44490 in 2014
#     (b) Least number of people killed: 173 in 1971
#
# 2.Region wise Attacks:
#     (a) Most number of people killed: 137642 in "Middle East & North Africa"
#     (b) Least number of people killed: 150 in "Australasia & Oceania"
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of people killed: 78589 in "Iraq"
#     (b) Least number of people killed: 12053 in "El Salvador"
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of people killed: 21151 in "Baghdad"
#     (b) Least number of people killed: 2125 in "Aleppo"
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of people killed : 38923 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of people killed : 5661 by "Revolutionary Armed Forces of Colombia (FARC)"
#
# 6.Attack Type wise Attacks:
#     (a) Most number of people killed : 160297 by "Armed Assault"
#     (b) Least number of people killed : 880 by "Unarmed Assault"
#
# 7.Target Type wise Attacks:
#     (a) Most number of people killed : 140504 over "Private Citizens & Property"
#     (b) Least number of people killed : 10 over "Abortion Related"
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of people killed : 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
#     (b) Least number of people killed : 6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#      Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868
#
# --------------------------------------------------------------------------------------------------------
# * WOUNDED
#
# Summary :PEOPLE WOUNDED
#
# 1.Year wise Attacks :
#     (a) Most number of people wounded: 44043 in 2015
#     (b) Least number of people wounded: 82 in 1971
#
# 2.Region wise Attacks :
#     (a) Most number of people wounded: 214308 in "Middle East & North Africa"
#     (b) Least number of people wounded: 260 in "Australasia & Oceania"
#
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of people wounded: 134690 in "Iraq"
#     (b) Least number of people wounded: 10328 in "Colombia"
#
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of people wounded: 56725 in "Baghdad"
#     (b) Least number of people wounded: 4955 in "Mogadishu"
#
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of people wounded : 30672 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of people wounded : 4908 by "Kurdistan Workers' Party (PKK)"
#
# 6.Attack Type wise Attacks:
#     (a) Most number of people wounded : 372686 by "Bombing/Explosion"
#     (b) Least number of people wounded : 3765 by "Facility/Infrastructure Attack"
#
#
#
# 7.Target Type wise Attacks:
#     (a) Most number of people wounded : 178672 over "Private Citizens & Property"
#     (b) Least number of people wounded : 46 over "Abortion Related"
#
#
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of people wounded : 27871 by "Taliban" in "Afghanistan"
#     (b) Least number of people wounded : 4795 by "Kurdistan Workers' Party (PKK)" in "Turkey"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#     Total number of people wounded due to Terrorist Attacks from 1970 to 2017 across the world : 523869.0
# ----------------------------------------------------------------------------------------------------------------
#
# * CASULATIES HAPPEN
#
# SUMMARY OF CASUALITIES HAPPEN :
# 1.Year wise Attacks :
#     (a) Most number of casualties: 85618 in 2014
#     (b) Least number of casualties: 255 in 1971
#
# 2.Region wise Attacks :
#     (a) Most number of casualties: 351950 in "Middle East & North Africa"
#     (b) Least number of casualties: 410 in Australasia & Oceania
#
# 3.Country wise Attacks [Top 10] :
#     (a) Most number of casualties: 213279 in "Iraq"
#     (b) Least number of casualties: 22926 in "Philippines"
#
# 4.City wise Attacks [Top 10] :
#     (a) Most number of casualties: 77876 in "Baghdad"
#     (b) Least number of casualties: 5748 in "Aleppo"
#
#
# 5.Terrorist Group wise Attacks [Top 10] :
#     (a) Most number of casualties : 69595 by "Islamic State of Iraq and the Levant (ISIL)"
#     (b) Least number of casualties : 12130 by "Farabundo Marti National Liberation Front (FMLN)"
#
#
# 6.Attack Type wise Attacks:
#     (a) Most number of casualties : 530007 by "Bombing/Explosion"
#     (b) Least number of casualties : 7407 by "Facility/Infrastructure Attack"
#
# 7.Target Type wise Attacks:
#     (a) Most number of casualties : 319176 over "Private Citizens & Property"
#     (b) Least number of casualties : 56 over "Abortion Related"
#
# 8.Group and Country wise Attacks [Top 10] :
#     (a) Most number of casualties : 57140 by "Taliban" in "Afghanistan"
#     (b) Least number of casualties : 12068 by "Farabundo Marti National Liberation Front (FMLN)" in "El Salvador"
#
# 9.Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#     Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : 935737
